# %%
import matplotlib
from matplotlib import pyplot
matplotlib.interactive(False)
matplotlib.use('Agg')
import os
import gc

# %%
corepath="/content/drive/MyDrive/Data_bird_mp3/"
melsPath= "/content/drive/MyDrive/Data_birds_melss/"

# %%
birds=[] # list of all birds
for root, dirs, files in os.walk(corepath):
    if root == corepath:
        birds=dirs
birds50=[]                
flist=[] # list of all files
blist=[] # list of files for one bird 
i50=0;
for i, bird in enumerate(birds):
    for root, dirs, files in os.walk(corepath+bird):
        for file in files:
            if file.endswith(".mp3"):
                blist.append(os.path.join(root, file))
    if len(blist) > 50:
        i50 = i50+1;
        print(i50, ". Found ", len(blist), ' files for ', bird ,'(',i+1,')')
        birds50.append(bird)
        flist.append(blist)
    blist=[]
# Out:
# 1 . Found  116  files for  Caprimulgusmacrurus ( 1 )
# 2 . Found  169  files for  Pnoepygapusilla ( 2 )
# 3 . Found  72  files for  Malacocinclasepiaria ( 3 )
# 4 . Found  76  files for  Malacopteronaffine ( 4 )
# 5 . Found  53  files for  Anthipessolitaris ( 5 )
# 6 . Found  80  files for  Anthracocerosalbirostris ( 6 )
# 7 . Found  113  files for  Corvusenca ( 7 )
# 8 . Found  96  files for  Dryocopusjavensis ( 8 )
# 9 . Found  247  files for  Elanuscaeruleus ( 9 )
# 10 . Found  92  files for  Orthotomussericeus ( 10 )
# 11 . Found  60  files for  Pachycephalacinerea ( 11 )
# 12 . Found  188  files for  Dicrurusparadiseus ( 12 )
# 13 . Found  201  files for  Phylloscopusborealis ( 13 )
# 14 . Found  141  files for  Eudynamysscolopaceus ( 14 )
# 15 . Found  143  files for  Macronusgularis ( 15 )

# %%
def saveMel(signal, directory):
    gc.enable()
    # MK_spectrogram modified
    n_fft = 1024          
    hop_size = 1024        
    n_mels = 128             
    win_size = 512      
    window_type = 'hann'  
    feature = 'mel'      
    fmin = 1400

    fig = plt.figure(1,frameon=False)   
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    
    S = librosa.feature.melspectrogram(y=signal, sr=sr,
                                        n_fft=n_fft,
                                        hop_length=hop_size, 
                                        n_mels=n_mels, 
                                        htk=True, 
                                        fmin=fmin, # higher limit ##high-pass filter freq.
                                        fmax=sr/2) # AMPLITUDE
    librosa.display.specshow(librosa.power_to_db(S**2,ref=np.max), fmin=fmin) #power = S**2

    fig.savefig(directory)
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')

# %%
import warnings
warnings.filterwarnings('ignore')

import sys
from tqdm import tqdm_notebook as tqdm
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

size = {'desired': 5, # [seconds]
        'minimum': 4, # [seconds]
        'stride' : 0, # [seconds]
        'name': 5 # [number of letters]
       } # stride should not be bigger than desired length

print('Number of directories to check and cut: ', len(flist))

#step = (size['desired']-size['stride'])*sr # length of step between two cuts in seconds
step=1
if step>0:
    for bird, birdList in enumerate(flist):
        print("Processing ",bird,'. ', birds50[bird], "...")
        for birdnr, path in tqdm(enumerate(birdList)):
            # load the mp3 file
            directory=melsPath+str(bird)+birds50[bird][:size['name']]+"/"

            if not os.path.exists(directory):
                os.makedirs(directory)
                
            if not os.path.exists(directory+path.rsplit('/',1)[1].replace(' ', '')[:-4]+"_1.png"):
                  
                signal, sr = librosa.load(path, sr=48000) # sr = sampling rate
                step = (size['desired']-size['stride'])*sr # length of step between two cuts in seconds
                
                nr=0;
                for start, end in zip(range(0,len(signal),step),range(size['desired']*sr,len(signal),step)):
                    # cut file and save each piece
                    nr=nr+1
                    # save the file if its length is higher than minimum
                    if end-start > size['minimum']*sr:
                        melpath=path.rsplit('/',1)[1]
                        melpath=directory+melpath.replace(' ', '')[:-4]+str(nr)+"_"+str(nr)+".png"
                        saveMel(signal[start:end],melpath)
                
            pass
else:    
    print("Error: Stride should be lower than desired length.")
# Out:
# Number of directories to check and cut:  15
# Processing  0 .  Caprimulgusmacrurus ...
# 0it [00:00, ?it/s]
# Processing  1 .  Pnoepygapusilla ...
# 0it [00:00, ?it/s]
# Processing  2 .  Malacocinclasepiaria ...
# 0it [00:00, ?it/s]
# Processing  3 .  Malacopteronaffine ...
# 0it [00:00, ?it/s]
# Processing  4 .  Anthipessolitaris ...
# 0it [00:00, ?it/s]
# Processing  5 .  Anthracocerosalbirostris ...
# 0it [00:00, ?it/s]
# Processing  6 .  Corvusenca ...
# 0it [00:00, ?it/s]
# Processing  7 .  Dryocopusjavensis ...
# 0it [00:00, ?it/s]
# Processing  8 .  Elanuscaeruleus ...
# 0it [00:00, ?it/s]
# Processing  9 .  Orthotomussericeus ...
# 0it [00:00, ?it/s]
# Processing  10 .  Pachycephalacinerea ...
# 0it [00:00, ?it/s]
# Processing  11 .  Dicrurusparadiseus ...
# 0it [00:00, ?it/s]
# Processing  12 .  Phylloscopusborealis ...
# 0it [00:00, ?it/s]
# Processing  13 .  Eudynamysscolopaceus ...
# 0it [00:00, ?it/s]
# Processing  14 .  Macronusgularis ...
# 0it [00:00, ?it/s]

# %%
glist=[]
for root, dirs, files in os.walk(melsPath):
    for file in files:
        if file.endswith(".png"):
            glist.append(os.path.join(root, file))
                
print('Found ', len(glist),' files.')
# Out:
# Found  16255  files.

# %%
mfccPath= "/content/drive/MyDrive/Birddata_mfcc/"

# %%
def saveMFCC(signal, directory):
    gc.enable()
    n_fft = 1024         # 
    hop_size = 1024      # 
    fig = plt.figure(1,frameon=False)
    fig.set_size_inches(6,6)

    ax = plt.Axes(fig, [0., 0., 1., 1.])
    ax.set_axis_off()
    fig.add_axes(ax)
    
    MFFCS = librosa.feature.mfcc(y=signal, sr=sr,
                                        n_fft=n_fft,
                                        hop_length=hop_size, 
                                        n_mfcc=40, 
                                        htk=True)
    librosa.display.specshow(MFFCS, sr=sr, hop_length=hop_size) 

    fig.savefig(directory)
    plt.ioff()
    #plt.show(block=False)
    fig.clf()
    ax.cla()
    plt.clf()
    plt.close('all')

# %%
import warnings
warnings.filterwarnings('ignore')

import sys
from tqdm import tqdm_notebook as tqdm
import librosa
import librosa.display
import numpy as np
import matplotlib.pyplot as plt

size = {'desired': 5, # [seconds]
        'minimum': 4, # [seconds]
        'stride' : 0, # [seconds]
        'name': 5 # [number of letters]
       } # stride should not be bigger than desired length

print('Number of directories to check and cut: ', len(flist))

#step = (size['desired']-size['stride'])*sr # length of step between two cuts in seconds
step=1
if step>0:
    for bird, birdList in enumerate(flist):
        print("Processing ",bird,'. ', birds50[bird], "...")
        for birdnr, path in tqdm(enumerate(birdList)):
            # load the mp3 file
            directory=mfccPath+str(bird)+birds50[bird][:size['name']]+"/"

            if not os.path.exists(directory):
                os.makedirs(directory)
                
            if not os.path.exists(directory+path.rsplit('/',1)[1].replace(' ', '')[:-4]+"_1.png"):
                  
                signal, sr = librosa.load(path, sr=48000) # sr = sampling rate
                step = (size['desired']-size['stride'])*sr # length of step between two cuts in seconds
                
                nr=0;
                for start, end in zip(range(0,len(signal),step),range(size['desired']*sr,len(signal),step)):
                    # cut file and save each piece
                    nr=nr+1
                    # save the file if its length is higher than minimum
                    if end-start > size['minimum']*sr:
                        mfccpath=path.rsplit('/',1)[1]
                        mfccpath=directory+mfccpath.replace(' ', '')[:-4]+str(nr)+"_"+str(nr)+".png"
                        saveMFCC(signal[start:end],mfccpath)
                    #print('New file...',start/sr,' - ',end/sr)
                    #print('Start: ',start,'end: ', end, 'length: ', end-start)
                
            pass
else:    
    print("Error: Stride should be lower than desired length.")
# Out:
# Number of directories to check and cut:  15
# Processing  0 .  Dryocopusjavensis ...
# 0it [00:00, ?it/s]
# Processing  1 .  Caprimulgusmacrurus ...
# 0it [00:00, ?it/s]
# Processing  2 .  Pnoepygapusilla ...
# 0it [00:00, ?it/s]
# Processing  3 .  Malacocinclamalaccensis ...
# 0it [00:00, ?it/s]
# Processing  4 .  Anthipessolitaris ...
# 0it [00:00, ?it/s]
# Processing  5 .  Orthotomussericeus ...
# 0it [00:00, ?it/s]
# Processing  6 .  Pycnonotusplumosus ...
# 0it [00:00, ?it/s]
# Processing  7 .  Malacocinclasepiaria ...
# 0it [00:00, ?it/s]
# Processing  8 .  Malacopteronaffine ...
# 0it [00:00, ?it/s]
# Processing  9 .  Pachycephalacinerea ...
# 0it [00:00, ?it/s]
# Processing  10 .  Pycnonotuserythropthalmos ...
# 0it [00:00, ?it/s]
# Processing  11 .  Corvusenca ...
# 0it [00:00, ?it/s]
# Processing  12 .  Elanuscaeruleus ...
# 0it [00:00, ?it/s]
# Processing  13 .  Anthracocerosalbirostris ...
# 0it [00:00, ?it/s]
# Processing  14 .  Dicrurusparadiseus ...
# 0it [00:00, ?it/s]

# %%
clist=[]
for root, dirs, files in os.walk(mfccPath):
    for file in files:
        if file.endswith(".png"):
            clist.append(os.path.join(root, file))
                
print('Found ', len(clist),' files.')
# Out:
# Found  13662  files.
